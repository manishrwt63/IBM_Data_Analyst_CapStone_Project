# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Visualize the distribution of data.
#
# *   Visualize the relationship between two features.
#
# *   Visualize composition of data.
#
# *   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2022-03-26 16:18:49--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  40.9MB/s    in 0.9s
#
# 2022-03-26 16:18:50 (40.9 MB/s) - ‘m4_survey_data.sqlite’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT*
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    index  Respondent                      MainBranch Hobbyist  \
# 0      0           4  I am a developer by profession       No
# 1      1           9  I am a developer by profession      Yes
# 2      2          13  I am a developer by profession      Yes
# 3      3          16  I am a developer by profession      Yes
# 4      4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# ...

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
import plotly.express as px
fig = px.histogram(df, x="ConvertedComp")
fig.show()
# Out:
# <div>                            <div id="e70b44a3-40a7-451a-b2b5-474d12faa116" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e70b44a3-40a7-451a-b2b5-474d12faa116")) {                    Plotly.newPlot(                        "e70b44a3-40a7-451a-b2b5-474d12faa116",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"ConvertedComp=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[61000.0,95179.0,90000.0,455352.0,65277.0,31140.0,41244.0,103000.0,69000.0,26388.0,6300.0,114000.0,100000.0,1100000.0,51312.0,156000.0,20623.0,87996.0,60000.0,5597.0,47300.0,68268.0,51150.0,97389.0,107000.
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.histplot(df.ConvertedComp)
# Out:
# <AxesSubplot:xlabel='ConvertedComp', ylabel='Count'>

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
px.box(df, x='Age')
# Out:
# <div>                            <div id="0adcdaee-3b57-4528-ad10-b199ad091ff4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0adcdaee-3b57-4528-ad10-b199ad091ff4")) {                    Plotly.newPlot(                        "0adcdaee-3b57-4528-ad10-b199ad091ff4",                        [{"alignmentgroup":"True","hovertemplate":"Age=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"type":"box","x":[22.0,23.0,28.0,26.0,29.0,31.0,38.0,47.0,22.0,23.0,22.0,34.0,32.0,21.0,44.0,42.0,27.0,43.0,34.0,23.0,18.0,37.0,33.0,31.0,27.0,34.0,19.0,24.0,29.0,42.0,21.0,24.0,27.0,32.0,25.0,24.0,22.0,26.0,26.0,36.0,25.0,35.0,27.0,30.0,25.0,39.0,37.0,29.0,41.0,26.0,54.0,2
# ...

# %%
sns.boxplot(x='Age', data=df);

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Age', y='WorkWeekHrs', data = df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='WorkWeekHrs'>

# %%
px.scatter(df, x='Age', y='WorkWeekHrs')
# Out:
# <div>                            <div id="c61d9613-b115-49d4-bd0b-9b9b4980c33a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c61d9613-b115-49d4-bd0b-9b9b4980c33a")) {                    Plotly.newPlot(                        "c61d9613-b115-49d4-bd0b-9b9b4980c33a",                        [{"hovertemplate":"Age=%{x}<br>WorkWeekHrs=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergl","x":[22.0,23.0,28.0,26.0,29.0,31.0,38.0,47.0,22.0,23.0,22.0,34.0,32.0,21.0,44.0,42.0,27.0,43.0,34.0,23.0,18.0,37.0,33.0,31.0,27.0,34.0,19.0,24.0,29.0,42.0,21.0,24.0,27.0,32.0,25.0,24.0,22.0,26.0,26.0,36.0,25.0,35.0,27.0,30.0,25.0,39.0,37.0,29.0,41.0,26.0,54.0,26.0,21.0,31.0,
# ...

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
plt.figure(figsize=(10,8))
plt.scatter(x=df.WorkWeekHrs, y=df.CodeRevHrs,alpha=0.2, s=df.Age*10)

# %%
px.scatter(df, x='WorkWeekHrs', y='CodeRevHrs')
# Out:
# <div>                            <div id="a3483500-4265-486c-ab53-28eaf2824468" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3483500-4265-486c-ab53-28eaf2824468")) {                    Plotly.newPlot(                        "a3483500-4265-486c-ab53-28eaf2824468",                        [{"hovertemplate":"WorkWeekHrs=%{x}<br>CodeRevHrs=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"type":"scattergl","x":[80.0,32.0,40.0,40.0,45.0,8.0,140.0,40.0,40.0,50.0,45.0,40.0,40.0,37.0,39.0,50.0,40.0,39.0,42.0,7.0,42.0,40.0,40.0,40.0,46.0,40.0,45.0,40.0,70.0,40.0,8.0,40.0,50.0,40.0,40.0,50.0,45.0,40.0,50.0,40.0,50.0,38.0,44.0,40.0,45.0,35.0,40.0,6.0,40.0,45.0,null,45.0,40.0,4
# ...

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
query = '''
select * from DatabaseDesireNextYear
'''


df=pd.read_sql_query(query, conn)

# %%
db_df=df.DatabaseDesireNextYear.value_counts().head(5).reset_index()

# %%
db_df1 = db_df.rename(columns={'index':'Database', 'DatabaseDesireNextYear':'Count'})

# %%
db_df1
# Out:
#         Database  Count
# 0     PostgreSQL   4328
# 1        MongoDB   3649
# 2          Redis   3331
# 3          MySQL   3281
# 4  Elasticsearch   2856

# %%
px.pie(db_df1, values='Count', names='Database')
# Out:
# <div>                            <div id="e6200a9c-74b1-42a6-b76c-a56ba984b4b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6200a9c-74b1-42a6-b76c-a56ba984b4b5")) {                    Plotly.newPlot(                        "e6200a9c-74b1-42a6-b76c-a56ba984b4b5",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Database=%{label}<br>Count=%{value}<extra></extra>","labels":["PostgreSQL","MongoDB","Redis","MySQL","Elasticsearch"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[4328,3649,3331,3281,2856]}],                        {"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6",
# ...

# %%
plt.pie(x=db_df1.Count, labels=db_df1.Database,autopct='%1.2f%%');

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
new_df1=df[(df.Age >= 30) & (df.Age <=35)]

# %%
new_df1[['WorkWeekHrs','CodeRevHrs']].describe()
# Out:
#        WorkWeekHrs   CodeRevHrs
# count  2917.000000  2379.000000
# mean     42.909479     4.784443
# std      24.753388     4.135441
# min       4.000000     0.000000
# 25%      40.000000     2.000000
# 50%      40.000000     4.000000
# 75%      42.000000     5.000000
# max     425.000000    54.000000

# %%
new_df1.groupby('Age')[['WorkWeekHrs', 'CodeRevHrs']].median().plot.bar(stacked=True)
plt.title('Median hours, by age')
# Out:
# Text(0.5, 1.0, 'Median hours, by age')

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
con_df = df.query('45 <= Age <= 60')

# %%
con_df.groupby('Age')['ConvertedComp'].median().plot.line()
plt.title('Median hours, by age')
# Out:
# Text(0.5, 1.0, 'Median hours, by age')

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
df.groupby('MainBranch')['MainBranch'].count().plot(kind='barh', figsize=(10, 6))
# Out:
# <AxesSubplot:ylabel='MainBranch'>

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
